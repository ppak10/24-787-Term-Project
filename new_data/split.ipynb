# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('new_data_merge.csv')
data
# Out:
#                    material  number_of_elements  mean_atomic_mass  \
# 0            Ag0.002Al0.998                 2.0         67.424869
# 1            Ag0.005Zn0.995                 2.0         86.624100
# 2      Ag0.035Cd0.01Sn0.955                 3.0        112.996400
# 3              Ag0.03Tl0.97                 2.0        156.125750
# 4        Ag0.05Rh0.04Ti0.91                 3.0         86.213567
# ...                     ...                 ...               ...
# 15537       Zr55Cu30Al10Ni5                 4.0         60.111235
# 15538      Zr62.4Ti15.6Ni22                 3.0         65.928133
# 15539      Zr66.3Ti11.7Ni22                 3.0         65.928133
# 15540       Zr70.2Ti7.8Ni22                 3.0         65.928133
# 15541       Zr74.1Ti3.9Ni22                 3.0         65.928133
#
#        wtd_mean_atomic_mass  gmean_atomic_mass  wtd_gmean_atomic_mass  \
# 0                 27.143312          53.948587              27.056422
# ...

# %%
train,test = train_test_split(data,train_size=0.66)

# %%
train
# Out:
#                       material  number_of_elements  mean_atomic_mass  \
# 14809           Y1Ba2Cu3F0.2O7                 5.0         64.955331
# 1892                    Bi2Pd1                 2.0        157.700200
# 14071  Y1Ba1.8La0.2Cu2.8Zn0.2O                 6.0         85.010620
# 9623             Nb3Sn0.9Al0.1                 3.0         79.532640
# 7555       La1Fe1As1F0.13O0.87                 5.0         60.933975
# ...                        ...                 ...               ...
# 11500        Sm0.45Ba0.55Cu1O3                 4.0         91.808100
# 248                     As1Ga1                 2.0         72.322300
# 11055       Rb0.8Fe2Se1.8Te0.2                 4.0         86.968200
# 2522    Bi4Sr4Ca0.5Eu1.5Cu4O16                 6.0         94.697967
# 10615             Pd0.07Ti0.93                 2.0         77.143500
#
#        wtd_mean_atomic_mass  gmean_atomic_mass  wtd_gmean_atomic_mass  \
# ...

# %%
train.to_csv('new_train.csv',index=None)

# %%
test
# Out:
#                             material  number_of_elements  mean_atomic_mass  \
# 7351         La1.985Sr0.015Cu1O4.032                 4.0         76.517718
# 8962          Na1Fe0.9825Co0.0175As1                 4.0         53.172391
# 11186                   Rh0.88Ti0.12                 2.0         75.386250
# 8158                      Lu1.2Mo6S8                 3.0        100.997267
# 2842            Ca0.835La0.165Fe2As2                 4.0         77.437517
# ...                              ...                 ...               ...
# 7922   La5.8Y0.4Ca0.8Ba3.1Cu7O16.548                 6.0         80.793620
# 12528    Tl0.5Pb0.5Sr2Ca0.9Y0.1Cu2O7                 7.0        101.104650
# 10172                       Ni24Zr76                 2.0         74.958700
# 9032                    Nb0.25Zr0.75                 2.0         92.065190
# 6857      La1.79Sr0.21Cu0.99Zn0.01O4                 5.0         74.290174
#
# ...

# %%
train_features = train.drop(train.columns[82:168], axis=1, inplace=True)
print(train_features)
# Out:
# None

# %%
train.iloc[:,82]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/hongshuh/Documents/GitHub/24-787-Term-Project/new_data/split.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/hongshuh/Documents/GitHub/24-787-Term-Project/new_data/split.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> train.iloc[:,82]
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1458, in _iLocIndexer._getitem_tuple(self, tup)
#    1456 def _getitem_tuple(self, tup: tuple):
# ...

# %%
train.iloc[:,168]
# Out:
# 14809    91.000000
# 1892      3.823333
# 14071    28.700000
# 9623     18.100000
# 7555     25.400000
#            ...
# 11500    69.000000
# 248       5.700000
# 11055    25.050000
# 2522      1.500000
# 10615     3.260000
# Name: critical_temp, Length: 10257, dtype: float64

# %%
test.to_csv('new_test.csv',index=None)

# %%
roost_train = pd.DataFrame(train,columns=['material','critical_temp']).reset_index()
roost_train.columns=['material_id','composition','target']
roost_test = pd.DataFrame(test,columns=['material','critical_temp']).reset_index()
roost_test.columns=['material_id','composition','target']

# %%
roost_train
# Out:
#        material_id              composition     target
# 0            14809           Y1Ba2Cu3F0.2O7  91.000000
# 1             1892                   Bi2Pd1   3.823333
# 2            14071  Y1Ba1.8La0.2Cu2.8Zn0.2O  28.700000
# 3             9623            Nb3Sn0.9Al0.1  18.100000
# 4             7555      La1Fe1As1F0.13O0.87  25.400000
# ...            ...                      ...        ...
# 10252        11500        Sm0.45Ba0.55Cu1O3  69.000000
# 10253          248                   As1Ga1   5.700000
# 10254        11055       Rb0.8Fe2Se1.8Te0.2  25.050000
# 10255         2522   Bi4Sr4Ca0.5Eu1.5Cu4O16   1.500000
# 10256        10615             Pd0.07Ti0.93   3.260000
#
# [10257 rows x 3 columns]

# %%
roost_train.to_csv('roost_train.csv',index=None)

# %%
roost_test.to_csv('roost_test.csv',index=None)
