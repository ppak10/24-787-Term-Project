# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
result = pd.read_csv('roost_result.csv')
result.columns
# Out:
# Index(['material_id', 'composition', 'target_pred_n0', 'target_target'], dtype='object')

# %%
pred = result['target_pred_n0'].to_numpy()
target = result['target_target'].to_numpy()

# %%
plt.plot(target,target,c='r')
plt.scatter(target,pred,alpha = 0.3)

# %% [markdown]
# R2 Score: 0.8937
# MAE: 6.3379
# RMSE: 10.9769
